# %%
from data_api import *
sm = ShareMessenger()
userId = sm.user.getUserId()
workspaceId = sm.workspace.getId()
channel = sm.getChannel(workspaceId)
generalChannelId = channel.select("general").getId()
announcementChannelId = channel.select("announcement", True).getId()
# Out:
# {
#   "uid": "f7f03f2c-eba0-46c4-be99-051d786055d3",
#   "idToken": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJmN2YwM2YyYy1lYmEwLTQ2YzQtYmU5OS0wNTFkNzg2MDU1ZDMiLCJ1c2VyIjp7InVpZCI6ImY3ZjAzZjJjLWViYTAtNDZjNC1iZTk5LTA1MWQ3ODYwNTVkMyIsImVtYWlsIjoia2htaW4xMTA0QGdtYWlsLmNvbSJ9LCJpYXQiOjE2ODY3MzYzMjYsImV4cCI6MTY4NjczOTkyNn0.lrbchCDKz1TyudEHNZqyNKvpXTVMd0dgQF8K-BKC87Y",
#   "refreshToken": "WA3KOrEGeqKZNujRmAcJpxcefwV3YRScGu4UDk1mnIUuZQhgU99boggbkya6fFFlvp0zQkNR8occMhqIHPzpIM6MoFTxiOxqPCIj",
#   "expires": 3600
# }
# {
#   "data": {
#     "listWorkspaces": [
#       {
#         "name": "enjoeyland",
#         "objectId": "9096e672-14fd-4373-b28c-606c9f0dc197",
#         "channelId": "016f1b60-54ff-49e4-a833-10ee04e33057",
#         "members": [
#           "f7f03f2c-eba0-46c4-be99-051d786055d3"
#         ]
#       }
#     ]
#   }
# }
# {
#   "data": {
#     "listChannels": [
#       {
#         "name": "general",
#         "objectId": "016f1b60-54ff-49e4-a833-10ee04e33057",
#         "announcementSubscribers": [],
#         "announcementPublishers": [
#           "4e4b7a2b-cda8-48c2-8569-6e0329a7fab8"
#         ]
#       },
#       {
#         "name": "announcement",
#         "objectId": "4e4b7a2b-cda8-48c2-8569-6e0329a7fab8",
#         "announcementSubscribers": [
#           "016f1b60-54ff-49e4-a833-10ee04e33057"
#         ],
#         "announcementPublishers": []
#       },
#       {
#         "name": "sw univ",
#         "objectId": "491c8809-f0a0-4fe1-b907-0a7d54caea10",
#         "announcementSubscribers": [
#           "7cfde0e2-1033-4125-8ca0-5e2c28fdbbc8",
#           "3b40ee32-cc22-44b6-b1f4-4c5e591d4a05"
#         ],
#         "announcementPublishers": []
#       },
#       {
#         "name": "sw",
#         "objectId": "3b40ee32-cc22-44b6-b1f4-4c5e591d4a05",
#         "announcementSubscribers": [
#           "7cfde0e2-1033-4125-8ca0-5e2c28fdbbc8"
#         ],
#         "announcementPublishers": [
#           "491c8809-f0a0-4fe1-b907-0a7d54caea10"
#         ]
#       },
#       {
#         "name": "sw20",
#         "objectId": "7cfde0e2-1033-4125-8ca0-5e2c28fdbbc8",
#         "announcementSubscribers": [],
#         "announcementPublishers": [
#           "491c8809-f0a0-4fe1-b907-0a7d54caea10",
#           "3b40ee32-cc22-44b6-b1f4-4c5e591d4a05"
#         ]
#       },
#       {
#         "name": "normal",
#         "objectId": "d9e6531b-cb40-4797-821a-8cd98e001528",
#         "announcementSubscribers": [],
#         "announcementPublishers": []
#       }
#     ]
#   }
# }

# %%
msgList = sm.graphqlQuery(f"""{{
    listMessages(chatId:"{announcementChannelId}") {{
        objectId
        text
        updatedAt
    }}
}}""")["listMessages"]
# Out:
# {
#   "data": {
#     "listMessages": [
#       {
#         "objectId": "f1cf7b16-b218-4cc5-83f4-e7ba761bd674",
#         "text": "<p>공지!</p>",
#         "updatedAt": "2023-06-14T09:50:59.780Z"
#       }
#     ]
#   }
# }

# %%
r = requests.post(f'{API_URL}/messages/{msgList[0]["objectId"]}/announce',
                   headers=sm.authorization_header,
                   verify=False)
print(r.text)
# Out:
# {
#   "success": true
# }

# %%
msgList = sm.graphqlQuery(f"""{{
    listMessages(chatId:"{generalChannelId}") {{
        objectId
        text
        updatedAt
    }}
}}""")["listMessages"]
# Out:
# {
#   "data": {
#     "listMessages": [
#       {
#         "objectId": "d8705398-4622-4cea-9ef5-4dc94df2dd89",
#         "text": "<p>공지!</p>",
#         "updatedAt": "2023-06-14T09:52:13.437Z"
#       },
#       {
#         "objectId": "683347a2-a03d-4ed8-817e-01a433a309bc",
#         "text": "<p>주간보고서</p>",
#         "updatedAt": "2023-06-14T04:42:48.555Z"
#       },
#       {
#         "objectId": "fe99717f-eccb-44dd-978d-7c731657eb98",
#         "text": "<p>주간보고서</p>",
#         "updatedAt": "2023-06-14T04:42:48.428Z"
#       },
#       {
#         "objectId": "3f15f1c0-d1dc-41d9-b4d1-fa4e49175331",
#         "text": "<p>주간보고서</p>",
#         "updatedAt": "2023-06-14T04:42:48.302Z"
#       },
#       {
#         "objectId": "4f566924-d364-4e74-acca-9d4b0d6d1e1b",
#         "text": "<p>주간보고서</p>",
#         "updatedAt": "2023-06-14T04:42:48.114Z"
#       },
#       {
#         "objectId": "d521a23a-6dfd-4e90-bbbc-17e34f4fe483",
#         "text": "<p>주간보고서</p>",
#         "updatedAt": "2023-06-14T04:42:47.565Z"
#       },
#       {
#         "objectId": "6775f3fc-5afd-4b71-aeae-32bb54152ca9",
#         "text": "<p>응앙</p>",
#         "updatedAt": "2023-06-14T04:34:00.733Z"
#       },
#       {
#         "objectId": "1db849cb-970d-4d47-b290-417f427e9f2e",
#         "text": "<p>응앙</p>",
#         "updatedAt": "2023-06-14T04:34:00.588Z"
#       },
#       {
#         "objectId": "d126bba3-564c-4eb1-a134-63a1eae9aa09",
#         "text": "<p>어떤가?</p>",
#         "updatedAt": "2023-06-14T04:26:58.506Z"
#       },
#       {
#         "objectId": "1e8bfc1a-c2dc-46ba-b76a-54d47c4c49e8",
#         "text": "<p>이건되나?</p>",
#         "updatedAt": "2023-06-14T04:19:05.227Z"
#       },
#       {
#         "objectId": "02637db6-09db-4fc8-ab56-8e70e68b6c79",
#         "text": "<p>뭐지?</p>",
#         "updatedAt": "2023-06-14T04:17:25.266Z"
#       },
#       {
#         "objectId": "cda3edc6-bcc2-4c79-8ed5-d6140c2b2bfc",
#         "text": "<p>ㅁㄴㅇㄹ</p>",
#         "updatedAt": "2023-06-14T04:16:56.332Z"
#       },
#       {
#         "objectId": "469b97da-75e7-4228-9159-5fc05d219e7d",
#         "text": "<p>제발돼</p>",
#         "updatedAt": "2023-06-14T04:10:39.614Z"
#       },
#       {
#         "objectId": "b9cc6faa-c331-4bd3-a2fc-4b77df43789a",
#         "text": "<p>주간보고서</p>",
#         "updatedAt": "2023-06-14T04:04:27.443Z"
#       },
#       {
#         "objectId": "e57598b1-8f45-4fc1-b4fd-88d9c6ae8bfc",
#         "text": "<p>scheduler 시현</p>",
#         "updatedAt": "2023-06-14T03:58:51.316Z"
#       },
#       {
#         "objectId": "5a0fac44-c5d8-4331-a746-59463514496a",
#         "text": "<p>주간보고서</p>",
#         "updatedAt": "2023-06-14T01:18:55.499Z"
#       },
#       {
#         "objectId": "190cd770-b345-4aa7-83df-204b5b3ca685",
#         "text": "<p>가위바위보</p>",
#         "updatedAt": "2023-06-14T01:17:49.501Z"
#       },
#       {
#         "objectId": "1079994d-1384-420f-af94-fdfeb075216e",
#         "text": "<p>기도제목</p>",
#         "updatedAt": "2023-06-14T01:01:59.965Z"
#       },
#       {
#         "objectId": "28ca0fac-f8a3-4278-9ec4-aa3363f78473",
#         "text": "<p>기도제목</p>",
#         "updatedAt": "2023-06-14T01:01:59.852Z"
#       },
#       {
#         "objectId": "c260cbbf-81aa-4e78-a9c0-b9c3fa4db921",
#         "text": "<p>기도제목</p>",
#         "updatedAt": "2023-06-14T00:44:37.738Z"
#       },
#       {
#         "objectId": "799dc8c4-c7ba-4caf-aa85-122b24acada5",
#         "text": "<p>안녕</p>",
#         "updatedAt": "2023-06-14T00:42:22.644Z"
#       }
#     ]
#   }
# }
